# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
packagename='pl.lukok.chess'

from google_play_scraper import Sort, reviews


us_reviews, continuation_token = reviews(
    packagename,
    count = 20000,
)


df_busu = pd.DataFrame(np.array(us_reviews),columns=['review'])# or
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu
# Out:
#                                    reviewId         userName  \
# 0      249f7008-a5be-4b2b-ac7a-ff783d882f17  satyaveeru guda
# 1      0445e9c6-475b-4d96-8678-998d7bcc5d2e    Vikas Jatothu
# 2      1c986a49-b981-4d16-93de-4a57f2b8fcfd      Tripoli Tek
# 3      6926ace3-d85c-4dad-b9a5-e54c4fc5ac39     satosh reddy
# 4      f5271346-bab5-43f2-8bba-3fa24b7c456a   mimoni gangkak
# ...                                     ...              ...
# 19995  1887361c-f8bd-4a72-a06f-8e56fd2b6a1a    A Google user
# 19996  0c84f118-d9c2-4a49-8257-9ac03968c962    A Google user
# 19997  7301b725-c0db-4fa2-8b51-98da051c34a3    A Google user
# 19998  199b8b63-f750-4204-97ad-84e472e4cdda    A Google user
# 19999  dbb4109d-1498-4439-be82-93b2151cdef4    A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ALm5wu...
# 1      https://play-lh.googleusercontent.com/a/ALm5wu...
# 2      https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
file=pd.read_csv('/Users/LENOVO/Project/'+packagename+'.csv')
file
# Out:
#          Package name        Reviewer name  \
# 0      pl.lukok.chess       Araitha Brahma
# 1      pl.lukok.chess       umesh ghongate
# 2      pl.lukok.chess       Sagar Mureliya
# 3      pl.lukok.chess  Deepak Deepak kumar
# 4      pl.lukok.chess       Sampad Samanta
# ...               ...                  ...
# 19995  pl.lukok.chess        A Google user
# 19996  pl.lukok.chess        A Google user
# 19997  pl.lukok.chess        A Google user
# 19998  pl.lukok.chess        A Google user
# 19999  pl.lukok.chess        A Google user
#
#                                                   Review  Rating
# 0                                                love it       4
# 1                                                   good       5
# 2                                                   full       5
# 3                                              nice game       3
# 4                                              very nice       5
# ...

# %%
count=0
for index,row in df_busu.iterrows():
    file.at[count,"Package name"]=packagename
    file.at[count,"Reviewer name"]=row["userName"]
    file.at[count,"Review"]=row["content"]
    file.at[count,"Rating"]=row["score"]
    count=count+1
file
# Out:
#          Package name    Reviewer name  \
# 0      pl.lukok.chess  satyaveeru guda
# 1      pl.lukok.chess    Vikas Jatothu
# 2      pl.lukok.chess      Tripoli Tek
# 3      pl.lukok.chess     satosh reddy
# 4      pl.lukok.chess   mimoni gangkak
# ...               ...              ...
# 19995  pl.lukok.chess    A Google user
# 19996  pl.lukok.chess    A Google user
# 19997  pl.lukok.chess    A Google user
# 19998  pl.lukok.chess    A Google user
# 19999  pl.lukok.chess    A Google user
#
#                                                   Review  Rating
# 0                                            खुप छान आहे       4
# 1                                                   Good       5
# 2                     I love the app it's just perfect 😍       5
# 3                                                   good       4
# 4      This is the worst app. you can play only 2 gam...       1
# ...                                                  ...     ...
# ...

# %%
file.to_csv('/Users/LENOVO/Project/'+packagename+'.csv',index=False)
file
# Out:
#          Package name    Reviewer name  \
# 0      pl.lukok.chess  satyaveeru guda
# 1      pl.lukok.chess    Vikas Jatothu
# 2      pl.lukok.chess      Tripoli Tek
# 3      pl.lukok.chess     satosh reddy
# 4      pl.lukok.chess   mimoni gangkak
# ...               ...              ...
# 19995  pl.lukok.chess    A Google user
# 19996  pl.lukok.chess    A Google user
# 19997  pl.lukok.chess    A Google user
# 19998  pl.lukok.chess    A Google user
# 19999  pl.lukok.chess    A Google user
#
#                                                   Review  Rating
# 0                                            खुप छान आहे       4
# 1                                                   Good       5
# 2                     I love the app it's just perfect 😍       5
# 3                                                   good       4
# 4      This is the worst app. you can play only 2 gam...       1
# ...                                                  ...     ...
# ...
